# %% [markdown]
# ### Distribución aleatoria uniforme sobre circulo y esfera

# %% [markdown]
# If the distribution is uniform
# the number of objects per
# unit volum is constant:
# In sphere is $$dn = r^{2} sin(\theta) d\theta dr d\phi$$

# %%
import numpy as np
import matplotlib.pyplot as plt

NumberRands = 1000
rand1 = np.random.rand(NumberRands)
rand2 = np.random.rand(NumberRands)

R=1
theta = (360*rand1)
r = (rand2)**(1/2)


fig = plt.figure()
ax = fig.add_subplot(projection='polar')
ax.set_rlim(0,2)
ax.scatter(theta, r)

# %% [markdown]
# Ahora con la esfera

# %%
ang = np.linspace(0,2*np.pi,100)
plt.scatter(r*np.cos(theta), r*np.sin(theta))
plt.plot(np.cos(ang),np.sin(ang), color= "red")
plt.axis('equal')
# Out:
# (-1.0994713695023444,
#  1.0999748271191592,
#  -1.0998615404412626,
#  1.0998615404412626)

# %%
N= 1000
rand3 = np.random.rand(N)
rand4 = np.random.rand(N)
rand5 = np.random.rand(N)

R=1
phi = 2*180*rand3
theta = np.arccos(1-2*rand4)
r = np.cbrt(rand5)

x = r*np.sin(theta)*np.cos(phi)
y = r*np.sin(theta)*np.sin(phi)
z = r*np.cos(theta)



fig = plt.figure(1,2)
ax = fig.add_subplot(projection='3d')
ax.scatter(x,y,z)
ax1 = fig.add_subplot()
ax1.scatter(x,y)
ax2 = fig.add_subplot()
ax2.scatter(y,z)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3200\2358359139.py in <module>
#      15
#      16
# ---> 17 fig = plt.figure(1,2)
#      18 ax = fig.add_subplot(projection='3d')
#      19 ax.scatter(x,y,z)
#
# c:\Users\SOPORTE\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     807             num, figsize=figsize, dpi=dpi,
#     808             facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
# --> 809             FigureClass=FigureClass, **kwargs)
#     810         fig = manager.canvas.figure
#     811         if fig_label:
#
# c:\Users\SOPORTE\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\pyplot.py in new_figure_manager(*args, **kwargs)
#     323     """Create a new figure manager instance."""
#     324     _warn_if_gui_out_of_main_thread()
# --> 325     return _get_backend_mod().new_figure_manager(*args, **kwargs)
#     326
#     327
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib_inline\backend_inline.py in new_figure_manager(num, FigureClass, *args, **kwargs)
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#      28
#      29
#
# c:\Users\SOPORTE\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\figure.py in __init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2342             raise ValueError('figure size must be positive finite not '
#    2343                              f'{figsize}')
# -> 2344         self.bbox_inches = Bbox.from_bounds(0, 0, *figsize)
#    2345
#    2346         self.dpi_scale_trans = Affine2D().scale(dpi)
#
# TypeError: from_bounds() argument after * must be an iterable, not int

# %%
#Rejection method
N = 10000
rand6  = np.random.rand(N)
rand7 = np.random.rand(N)
rand8 = np.random.rand(N)

R = 1
x = 2*R*rand6 - R
y = 2*R*rand7 - R
z = 2*R*rand8 - R

x_g = []
y_g = []
z_g = []

for i in range(N):
    if x[i]**2 +y[i]**2+z[i]**2 < R**2:
        x_g.append(x[i])
        y_g.append(y[i])
        z_g.append(z[i])
    else:
        None


fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x_g,y_g,z_g, s=5)
plt.show()
