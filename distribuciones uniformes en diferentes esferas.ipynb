# %% [markdown]
# ### Distribución aleatoria uniforme sobre circulo y esfera

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(1000)


R=1
theta = (360*x)
r = (2*x)**(1/2)


fig = plt.figure()
ax = fig.add_subplot(projection='polar')
ax.set_rlim(0,2)
c = ax.scatter(theta, r)

# %% [markdown]
# Ahora con la esfera

# %%
plt.scatter(r*np.cos(theta), r*np.sin(theta))

# %%
N= 100000
y = np.random.rand(N)

R=1
phi = 360*y
theta = np.arccos(y)
r = np.cbrt(3*y)

fig = plt.figure()
ax = fig.add_subplot(projection='3D')
ax.set_rlim(0,2)
c = ax.scatter(theta, r, phi)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\SOPORTE\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\projections\__init__.py in get_projection_class(projection)
#     107     try:
# --> 108         return projection_registry.get_projection_class(projection)
#     109     except KeyError as err:
#
# c:\Users\SOPORTE\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\projections\__init__.py in get_projection_class(self, name)
#      74         """Get a projection class from its *name*."""
# ---> 75         return self._all_projection_types[name]
#      76
#
# KeyError: '3D'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3640\3918056952.py in <module>
#       8
#       9 fig = plt.figure()
# ---> 10 ax = fig.add_subplot(projection='3D')
#      11 ax.set_rlim(0,2)
#      12 c = ax.scatter(theta, r, phi)
#
# c:\Users\SOPORTE\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#     769                 args = tuple(map(int, str(args[0])))
#     770             projection_class, pkw = self._process_projection_requirements(
# --> 771                 *args, **kwargs)
#     772             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773             key = (projection_class, pkw)
#
# c:\Users\SOPORTE\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\figure.py in _process_projection_requirements(self, axes_class, polar, projection, *args, **kwargs)
#    1628
#    1629             if isinstance(projection, str) or projection is None:
# -> 1630                 projection_class = projections.get_projection_class(projection)
#    1631             elif hasattr(projection, '_as_mpl_axes'):
#    1632                 projection_class, extra_kwargs = projection._as_mpl_axes()
#
# c:\Users\SOPORTE\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\projections\__init__.py in get_projection_class(projection)
#     108         return projection_registry.get_projection_class(projection)
#     109     except KeyError as err:
# --> 110         raise ValueError("Unknown projection %r" % projection) from err
#     111
#     112
#
# ValueError: Unknown projection '3D'
